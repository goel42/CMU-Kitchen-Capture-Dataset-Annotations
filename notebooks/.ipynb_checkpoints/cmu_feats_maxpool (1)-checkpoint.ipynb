# %%
import cv2
import os
import itertools
import numpy as np
import pandas as pd
import json

# %%
activity = "Eggs"
feats_dir_orig = "/mnt/data/ar-datasets/cmu-kitchen/features2"
feats_dir_orig = os.path.join(feats_dir_orig, activity)


feats_dir_maxpool = "/mnt/data/ar-datasets/cmu-kitchen/features_maxpool"
feats_dir_maxpool = os.path.join(feats_dir_maxpool, "all")

if not os.path.exists(feats_dir_maxpool):
    os.makedirs(feats_dir_maxpool)

offset_file = "/mnt/data/ar-datasets/cmu-kitchen/annotation/offset_"+activity+".txt"
offset = json.load(open(offset_file))

gt_maxpool_dir = "/mnt/data/ar-datasets/cmu-kitchen/annotation/groundtruth_maxpool"
gt_maxpool_dir = os.path.join(gt_maxpool_dir,"all")

if not os.path.exists(gt_maxpool_dir):
    os.makedirs(gt_maxpool_dir)

gt_file = "/mnt/data/ar-datasets/cmu-kitchen/annotation/cmuK_"+activity+"_new.xlsx"
xls = pd.ExcelFile(gt_file)
gt_all = pd.read_excel(xls, sheet_name=None)
gt_all.keys()

mapping_file = "/mnt/data/ar-datasets/cmu-kitchen/annotation/mapping_"+activity+".txt"
mapping = pd.read_excel(xls, sheet_name = "stats", header=None)
mapping[0] = mapping[0].str.split("'").str.get(1)
mapping.to_csv(os.path.join(mapping_file), sep=' ', index=True, header=False)

# %%
#CREATE FINAL GROUPED FILE
for subject in list(gt_all.keys()): #excluding key=stats
    if subject == "stats":
        continue
    try:
#         print(subject)
        df = gt_all[subject]
        df2 = df.loc[df["Grouped Labels"].notnull()]
        df3 = df2[df2.columns[2: ]]
        temp =  df.loc[df["Original Labels"]=="(FINISHED)", "Start Time"]
        end_times = df3["Start Time"][1: ].append(temp)
        df3["End Time"] = end_times.values
        df3["Start Time"]+= offset[subject]
        df3["End Time"]+= offset[subject]
        gt_all[subject] = df3
    except Exception as e:
        print(subject, e)
# Out:
# S07 'Original Labels'
# S09 'Original Labels'
# S11 'Original Labels'
# S12 'Original Labels'
# S13 'Original Labels'
# S14 'Original Labels'
# S15 'Original Labels'
# S16 'Original Labels'
# S18 'Original Labels'
# S19 'Original Labels'
# S20 'Original Labels'
# S25 'Original Labels'
# S28 'Original Labels'
# S29 'Original Labels'
# S30 'Original Labels'
# S31 'Original Labels'
# S32 'Original Labels'
# S34 'Original Labels'
# S35 'Original Labels'
# S36 'Original Labels'
# S40 'Original Labels'
# S47 'Original Labels'
# S48 'Original Labels'
# S50 'Original Labels'
# S51 'Original Labels'
# S53 'Original Labels'
# S54 'Original Labels'
# S55 'Original Labels'

# %%
# # print (round (gt_all["S37"]["Start Time"]*0.03).astype(int) , (gt_all["S37"]["Start Time"]*0.03))
# gt_all["S37"]

# for idx, label in gt_all["S37"].iterrows():
#     print(idx, label["Start Time"])

# %%
# print final anotation labels

# %%
feats_files = os.listdir(feats_dir_orig) 
feats_files = sorted(feats_files)
#REMOVE temporary because last two files not maxpooled in curr dir
# feats_files = [file for file in feats_files if ".npy" in file]
# feats_files = feats_files[:-1]


feats_subjects = [list(g) for _,g in itertools.groupby(feats_files, lambda x: x.split('_')[0])]
feats_subjects
# Out:
# [['S07_Eggs_6510211.npy',
#   'S07_Eggs_7150991.npy',
#   'S07_Eggs_7151020.npy',
#   'S07_Eggs_7151062.npy',
#   'S07_Eggs_8421130.npy'],
#  ['S08_Eggs_6510211.npy',
#   'S08_Eggs_7150991.npy',
#   'S08_Eggs_7151020.npy',
#   'S08_Eggs_7151062.npy',
#   'S08_Eggs_8421130.npy'],
#  ['S09_Eggs_6510211.npy',
#   'S09_Eggs_7150991.npy',
#   'S09_Eggs_7151020.npy',
#   'S09_Eggs_7151062.npy',
#   'S09_Eggs_8421130.npy'],
#  ['S11_Eggs_6510211.npy',
#   'S11_Eggs_7150991.npy',
#   'S11_Eggs_7151020.npy',
#   'S11_Eggs_7151062.npy',
#   'S11_Eggs_8421130.npy'],
#  ['S12_Eggs_6510211.npy',
#   'S12_Eggs_7150991.npy',
#   'S12_Eggs_7151020.npy',
#   'S12_Eggs_7151062.npy',
#   'S12_Eggs_8421130.npy'],
#  ['S13_Eggs_6510211.npy',
#   'S13_Eggs_7150991.npy',
#   'S13_Eggs_7151020.npy',
#   'S13_Eggs_7151062.npy',
#   'S13_Eggs_8421130.npy'],
#  ['S14_Eggs_6510211.npy',
#   'S14_Eggs_7150991.npy',
#   'S14_Eggs_7151020.npy',
#   'S14_Eggs_7151062.npy',
#   'S14_Eggs_8421130.npy'],
#  ['S15_Eggs_6510211.npy',
#   'S15_Eggs_7150991.npy',
#   'S15_Eggs_7151020.npy',
#   'S15_Eggs_7151062.npy',
#   'S15_Eggs_8421130.npy'],
#  ['S16_Eggs_6510211.npy',
#   'S16_Eggs_7150991.npy',
#   'S16_Eggs_7151020.npy',
#   'S16_Eggs_7151062.npy',
#   'S16_Eggs_8421130.npy'],
#  ['S17_Eggs_6510211.npy',
#   'S17_Eggs_7150991.npy',
#   'S17_Eggs_7151020.npy',
#   'S17_Eggs_7151062.npy',
#   'S17_Eggs_8421130.npy'],
#  ['S18_Eggs_6510211.npy',
#   'S18_Eggs_7150991.npy',
#   'S18_Eggs_7151020.npy',
#   'S18_Eggs_7151062.npy',
#   'S18_Eggs_8421130.npy'],
#  ['S19_Eggs_6510211.npy',
#   'S19_Eggs_7150991.npy',
#   'S19_Eggs_7151020.npy',
#   'S19_Eggs_7151062.npy',
#   'S19_Eggs_8421130.npy'],
#  ['S20_Eggs_6510211.npy',
#   'S20_Eggs_7150991.npy',
#   'S20_Eggs_7151020.npy',
#   'S20_Eggs_7151062.npy',
#   'S20_Eggs_8421130.npy'],
#  ['S25_Eggs_6510211.npy',
#   'S25_Eggs_7150991.npy',
#   'S25_Eggs_7151020.npy',
#   'S25_Eggs_7151062.npy',
#   'S25_Eggs_8421130.npy'],
#  ['S28_Eggs_6510211.npy',
#   'S28_Eggs_7150991.npy',
#   'S28_Eggs_7150996.npy',
#   'S28_Eggs_7151020.npy',
#   'S28_Eggs_7151062.npy',
#   'S28_Eggs_8421130.npy'],
#  ['S29_Eggs_6510211.npy',
#   'S29_Eggs_7150991.npy',
#   'S29_Eggs_7150996.npy',
#   'S29_Eggs_7151020.npy',
#   'S29_Eggs_7151062.npy',
#   'S29_Eggs_8421130.npy'],
#  ['S30_Eggs_6510211.npy',
#   'S30_Eggs_7150991.npy',
#   'S30_Eggs_7150996.npy',
#   'S30_Eggs_7151020.npy',
#   'S30_Eggs_7151062.npy',
#   'S30_Eggs_8421130.npy'],
#  ['S31_Eggs_6510211.npy',
#   'S31_Eggs_7150991.npy',
#   'S31_Eggs_7150996.npy',
#   'S31_Eggs_7151020.npy',
#   'S31_Eggs_7151062.npy',
#   'S31_Eggs_8421130.npy'],
#  ['S32_Eggs_6510211.npy',
#   'S32_Eggs_7150991.npy',
#   'S32_Eggs_7150996.npy',
#   'S32_Eggs_7151020.npy',
#   'S32_Eggs_7151062.npy',
#   'S32_Eggs_8421130.npy'],
#  ['S33_Eggs_6510211.npy',
#   'S33_Eggs_7150991.npy',
#   'S33_Eggs_7150996.npy',
#   'S33_Eggs_7151020.npy',
#   'S33_Eggs_7151062.npy',
#   'S33_Eggs_8421130.npy'],
#  ['S34_Eggs_6510211.npy',
#   'S34_Eggs_7150991.npy',
#   'S34_Eggs_7150996.npy',
#   'S34_Eggs_7151020.npy',
#   'S34_Eggs_7151062.npy',
#   'S34_Eggs_8421130.npy'],
#  ['S35_Eggs_6510211.npy',
#   'S35_Eggs_7150991.npy',
#   'S35_Eggs_7150996.npy',
#   'S35_Eggs_7151020.npy',
#   'S35_Eggs_7151062.npy',
#   'S35_Eggs_8421130.npy'],
#  ['S36_Eggs_6510211.npy',
#   'S36_Eggs_7150991.npy',
#   'S36_Eggs_7150996.npy',
#   'S36_Eggs_7151020.npy',
#   'S36_Eggs_7151062.npy',
#   'S36_Eggs_8421130.npy'],
#  ['S37_Eggs_6510211.npy',
#   'S37_Eggs_7150991.npy',
#   'S37_Eggs_7150996.npy',
#   'S37_Eggs_7151020.npy',
#   'S37_Eggs_7151062.npy',
#   'S37_Eggs_8421130.npy'],
#  ['S40_Eggs_6510211.npy',
#   'S40_Eggs_7150991.npy',
#   'S40_Eggs_7150996.npy',
#   'S40_Eggs_7151020.npy',
#   'S40_Eggs_7151062.npy',
#   'S40_Eggs_8421130.npy'],
#  ['S41_Eggs_6510211.npy',
#   'S41_Eggs_7150991.npy',
#   'S41_Eggs_7150996.npy',
#   'S41_Eggs_7151020.npy',
#   'S41_Eggs_7151062.npy',
#   'S41_Eggs_8421130.npy'],
#  ['S47_Eggs_6510211.npy',
#   'S47_Eggs_7150991.npy',
#   'S47_Eggs_7150996.npy',
#   'S47_Eggs_7151020.npy',
#   'S47_Eggs_7151062.npy',
#   'S47_Eggs_8421130.npy'],
#  ['S48_Eggs_6510211.npy',
#   'S48_Eggs_7150991.npy',
#   'S48_Eggs_7150996.npy',
#   'S48_Eggs_7151020.npy',
#   'S48_Eggs_7151062.npy',
#   'S48_Eggs_8421130.npy'],
#  ['S49_Eggs_6510211.npy',
#   'S49_Eggs_7150991.npy',
#   'S49_Eggs_7150996.npy',
#   'S49_Eggs_7151020.npy',
#   'S49_Eggs_7151062.npy',
#   'S49_Eggs_8421130.npy'],
#  ['S50_Eggs_6510211.npy',
#   'S50_Eggs_7150991.npy',
#   'S50_Eggs_7150996.npy',
#   'S50_Eggs_7151020.npy',
#   'S50_Eggs_7151062.npy',
#   'S50_Eggs_8421130.npy'],
#  ['S51_Eggs_6510211.npy',
#   'S51_Eggs_7150991.npy',
#   'S51_Eggs_7150996.npy',
#   'S51_Eggs_7151020.npy',
#   'S51_Eggs_7151062.npy',
#   'S51_Eggs_8421130.npy'],
#  ['S52_Eggs_6510211.npy',
#   'S52_Eggs_7150996.npy',
#   'S52_Eggs_7151020.npy',
#   'S52_Eggs_7151062.npy',
#   'S52_Eggs_8421130.npy'],
#  ['S53_Eggs_6510211.npy',
#   'S53_Eggs_7150991.npy',
#   'S53_Eggs_7150996.npy',
#   'S53_Eggs_7151020.npy',
#   'S53_Eggs_7151062.npy',
#   'S53_Eggs_8421130.npy'],
#  ['S54_Eggs_6510211.npy',
#   'S54_Eggs_7150991.npy',
#   'S54_Eggs_7150996.npy',
#   'S54_Eggs_7151020.npy',
#   'S54_Eggs_7151062.npy',
#   'S54_Eggs_8421130.npy'],
#  ['S55_Eggs_6510211.npy',
#   'S55_Eggs_7150991.npy',
#   'S55_Eggs_7150996.npy',
#   'S55_Eggs_7151020.npy',
#   'S55_Eggs_7151062.npy',
#   'S55_Eggs_8421130.npy']]

# %%
def get_maxpool_feats(feat, gt):
    
    feat_maxpool = np.zeros([gt.shape[0], feat.shape[1]])
    idx=0
    for _, label in gt.iterrows():
        st_frame = round(label["Start Time"]*0.03) #time(in ms ) to frame number conversion
        end_frame = round(label["End Time"]*0.03)
#         print("start end frame: ", st_frame, end_frame)
#         print(feat.shape)
        bro = np.max(feat[st_frame:end_frame], axis=0)
        feat_maxpool[idx]= bro
        idx+=1
#     print(feat.shape, feat_maxpool.shape, gt.shape)
    return feat_maxpool

# %%
for subject in feats_subjects:
    try:
        if subject[0].split("_")[0] in gt_all.keys():
            for viewpoint in subject:
                feat_filename = viewpoint.split(".")[0]
                feat = np.load(os.path.join(feats_dir_orig, viewpoint))
                feat_maxpool = get_maxpool_feats(feat, gt_all[feat_filename.split("_")[0]])
#                 print(viewpoint, feat.shape, feat_maxpool.shape)
                temp = gt_all[feat_filename.split("_")[0]]["Grouped Labels"]
#                 print(temp)
                temp.to_csv(os.path.join(gt_maxpool_dir, feat_filename+".txt"), sep='\n', index=False, header=False)
#                 break
#         break
                np.save(os.path.join(feats_dir_maxpool, feat_filename+".npy"), feat_maxpool)
    except Exception as e:
        print(subject[0], e)
# Out:
# S07_Eggs_6510211.npy
# Grouped Labels    take_bowl
# Start Time             9226
# End Time              17653
# Name: 1, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    take_egg
# Start Time           17653
# End Time             26906
# Name: 5, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    crack_egg
# Start Time            26906
# End Time              37600
# Name: 12, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time           37600
# End Time             55388
# Name: 20, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      55388
# End Time                        69618
# Name: 24, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time           69618
# End Time             72670
# Name: 34, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    put_pan
# Start Time          72670
# End Time            77878
# Name: 38, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    put_oil_butter
# Start Time                 77878
# End Time                  106261
# Name: 42, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    take_plate
# Start Time            106261
# End Time              111013
# Name: 56, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time          111013
# End Time            125670
# Name: 60, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 125670
# End Time                   143267
# Name: 64, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    remove_utensils
# Start Time                 143267
# End Time                   325028
# Name: 70, dtype: object
# S07_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   325028
# End Time                     359239
# Name: 80, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    take_bowl
# Start Time             9226
# End Time              17653
# Name: 1, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    take_egg
# Start Time           17653
# End Time             26906
# Name: 5, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    crack_egg
# Start Time            26906
# End Time              37600
# Name: 12, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time           37600
# End Time             55388
# Name: 20, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      55388
# End Time                        69618
# Name: 24, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time           69618
# End Time             72670
# Name: 34, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    put_pan
# Start Time          72670
# End Time            77878
# Name: 38, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    put_oil_butter
# Start Time                 77878
# End Time                  106261
# Name: 42, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    take_plate
# Start Time            106261
# End Time              111013
# Name: 56, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time          111013
# End Time            125670
# Name: 60, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 125670
# End Time                   143267
# Name: 64, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    remove_utensils
# Start Time                 143267
# End Time                   325028
# Name: 70, dtype: object
# S07_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   325028
# End Time                     359239
# Name: 80, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    take_bowl
# Start Time             9226
# End Time              17653
# Name: 1, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    take_egg
# Start Time           17653
# End Time             26906
# Name: 5, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    crack_egg
# Start Time            26906
# End Time              37600
# Name: 12, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time           37600
# End Time             55388
# Name: 20, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      55388
# End Time                        69618
# Name: 24, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time           69618
# End Time             72670
# Name: 34, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    put_pan
# Start Time          72670
# End Time            77878
# Name: 38, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    put_oil_butter
# Start Time                 77878
# End Time                  106261
# Name: 42, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    take_plate
# Start Time            106261
# End Time              111013
# Name: 56, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time          111013
# End Time            125670
# Name: 60, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 125670
# End Time                   143267
# Name: 64, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    remove_utensils
# Start Time                 143267
# End Time                   325028
# Name: 70, dtype: object
# S07_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   325028
# End Time                     359239
# Name: 80, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    take_bowl
# Start Time             9226
# End Time              17653
# Name: 1, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    take_egg
# Start Time           17653
# End Time             26906
# Name: 5, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    crack_egg
# Start Time            26906
# End Time              37600
# Name: 12, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time           37600
# End Time             55388
# Name: 20, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      55388
# End Time                        69618
# Name: 24, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time           69618
# End Time             72670
# Name: 34, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    put_pan
# Start Time          72670
# End Time            77878
# Name: 38, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    put_oil_butter
# Start Time                 77878
# End Time                  106261
# Name: 42, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    take_plate
# Start Time            106261
# End Time              111013
# Name: 56, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time          111013
# End Time            125670
# Name: 60, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 125670
# End Time                   143267
# Name: 64, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    remove_utensils
# Start Time                 143267
# End Time                   325028
# Name: 70, dtype: object
# S07_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   325028
# End Time                     359239
# Name: 80, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    take_bowl
# Start Time             9226
# End Time              17653
# Name: 1, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    take_egg
# Start Time           17653
# End Time             26906
# Name: 5, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    crack_egg
# Start Time            26906
# End Time              37600
# Name: 12, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time           37600
# End Time             55388
# Name: 20, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      55388
# End Time                        69618
# Name: 24, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time           69618
# End Time             72670
# Name: 34, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    put_pan
# Start Time          72670
# End Time            77878
# Name: 38, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    put_oil_butter
# Start Time                 77878
# End Time                  106261
# Name: 42, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    take_plate
# Start Time            106261
# End Time              111013
# Name: 56, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time          111013
# End Time            125670
# Name: 60, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 125670
# End Time                   143267
# Name: 64, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    remove_utensils
# Start Time                 143267
# End Time                   325028
# Name: 70, dtype: object
# S07_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   325028
# End Time                     359239
# Name: 80, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    take_plate
# Start Time              6997
# Unnamed: 4               NaN
# End Time               12357
# Name: 1, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    take_bowl
# Start Time            12357
# Unnamed: 4              NaN
# End Time              15356
# Name: 4, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    take_mixing_tool
# Start Time                   15356
# Unnamed: 4               take_fork
# End Time                     19238
# Name: 7, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    put_pan
# Start Time          19238
# Unnamed: 4            NaN
# End Time            27904
# Name: 11, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    put_oil_butter
# Start Time                 27904
# Unnamed: 4                   NaN
# End Time                   43526
# Name: 16, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    take_egg
# Start Time           43526
# Unnamed: 4             NaN
# End Time             53570
# Name: 25, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    crack_egg
# Start Time            53570
# Unnamed: 4              NaN
# End Time              65148
# Name: 32, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    clean_hands
# Start Time              65148
# Unnamed: 4                NaN
# End Time                73601
# Name: 38, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time           73601
# Unnamed: 4             NaN
# End Time             79787
# Name: 44, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      79787
# Unnamed: 4                        NaN
# End Time                        92127
# Name: 47, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time           92127
# Unnamed: 4             NaN
# End Time            123166
# Name: 55, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 123166
# Unnamed: 4                    NaN
# End Time                   196355
# Name: 59, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   196355
# Unnamed: 4                      NaN
# End Time                     210302
# Name: 70, dtype: object
# S09_Eggs_6510211.npy
# Grouped Labels    clean_hands
# Start Time             210302
# Unnamed: 4                NaN
# End Time               216300
# Name: 76, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    take_plate
# Start Time              6997
# Unnamed: 4               NaN
# End Time               12357
# Name: 1, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    take_bowl
# Start Time            12357
# Unnamed: 4              NaN
# End Time              15356
# Name: 4, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    take_mixing_tool
# Start Time                   15356
# Unnamed: 4               take_fork
# End Time                     19238
# Name: 7, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    put_pan
# Start Time          19238
# Unnamed: 4            NaN
# End Time            27904
# Name: 11, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    put_oil_butter
# Start Time                 27904
# Unnamed: 4                   NaN
# End Time                   43526
# Name: 16, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    take_egg
# Start Time           43526
# Unnamed: 4             NaN
# End Time             53570
# Name: 25, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    crack_egg
# Start Time            53570
# Unnamed: 4              NaN
# End Time              65148
# Name: 32, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    clean_hands
# Start Time              65148
# Unnamed: 4                NaN
# End Time                73601
# Name: 38, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time           73601
# Unnamed: 4             NaN
# End Time             79787
# Name: 44, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      79787
# Unnamed: 4                        NaN
# End Time                        92127
# Name: 47, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time           92127
# Unnamed: 4             NaN
# End Time            123166
# Name: 55, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 123166
# Unnamed: 4                    NaN
# End Time                   196355
# Name: 59, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   196355
# Unnamed: 4                      NaN
# End Time                     210302
# Name: 70, dtype: object
# S09_Eggs_7150991.npy
# Grouped Labels    clean_hands
# Start Time             210302
# Unnamed: 4                NaN
# End Time               216300
# Name: 76, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    take_plate
# Start Time              6997
# Unnamed: 4               NaN
# End Time               12357
# Name: 1, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    take_bowl
# Start Time            12357
# Unnamed: 4              NaN
# End Time              15356
# Name: 4, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    take_mixing_tool
# Start Time                   15356
# Unnamed: 4               take_fork
# End Time                     19238
# Name: 7, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    put_pan
# Start Time          19238
# Unnamed: 4            NaN
# End Time            27904
# Name: 11, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    put_oil_butter
# Start Time                 27904
# Unnamed: 4                   NaN
# End Time                   43526
# Name: 16, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    take_egg
# Start Time           43526
# Unnamed: 4             NaN
# End Time             53570
# Name: 25, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    crack_egg
# Start Time            53570
# Unnamed: 4              NaN
# End Time              65148
# Name: 32, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    clean_hands
# Start Time              65148
# Unnamed: 4                NaN
# End Time                73601
# Name: 38, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time           73601
# Unnamed: 4             NaN
# End Time             79787
# Name: 44, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      79787
# Unnamed: 4                        NaN
# End Time                        92127
# Name: 47, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time           92127
# Unnamed: 4             NaN
# End Time            123166
# Name: 55, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 123166
# Unnamed: 4                    NaN
# End Time                   196355
# Name: 59, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   196355
# Unnamed: 4                      NaN
# End Time                     210302
# Name: 70, dtype: object
# S09_Eggs_7151020.npy
# Grouped Labels    clean_hands
# Start Time             210302
# Unnamed: 4                NaN
# End Time               216300
# Name: 76, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    take_plate
# Start Time              6997
# Unnamed: 4               NaN
# End Time               12357
# Name: 1, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    take_bowl
# Start Time            12357
# Unnamed: 4              NaN
# End Time              15356
# Name: 4, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    take_mixing_tool
# Start Time                   15356
# Unnamed: 4               take_fork
# End Time                     19238
# Name: 7, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    put_pan
# Start Time          19238
# Unnamed: 4            NaN
# End Time            27904
# Name: 11, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    put_oil_butter
# Start Time                 27904
# Unnamed: 4                   NaN
# End Time                   43526
# Name: 16, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    take_egg
# Start Time           43526
# Unnamed: 4             NaN
# End Time             53570
# Name: 25, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    crack_egg
# Start Time            53570
# Unnamed: 4              NaN
# End Time              65148
# Name: 32, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    clean_hands
# Start Time              65148
# Unnamed: 4                NaN
# End Time                73601
# Name: 38, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time           73601
# Unnamed: 4             NaN
# End Time             79787
# Name: 44, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      79787
# Unnamed: 4                        NaN
# End Time                        92127
# Name: 47, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time           92127
# Unnamed: 4             NaN
# End Time            123166
# Name: 55, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 123166
# Unnamed: 4                    NaN
# End Time                   196355
# Name: 59, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   196355
# Unnamed: 4                      NaN
# End Time                     210302
# Name: 70, dtype: object
# S09_Eggs_7151062.npy
# Grouped Labels    clean_hands
# Start Time             210302
# Unnamed: 4                NaN
# End Time               216300
# Name: 76, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    take_plate
# Start Time              6997
# Unnamed: 4               NaN
# End Time               12357
# Name: 1, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    take_bowl
# Start Time            12357
# Unnamed: 4              NaN
# End Time              15356
# Name: 4, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    take_mixing_tool
# Start Time                   15356
# Unnamed: 4               take_fork
# End Time                     19238
# Name: 7, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    put_pan
# Start Time          19238
# Unnamed: 4            NaN
# End Time            27904
# Name: 11, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    put_oil_butter
# Start Time                 27904
# Unnamed: 4                   NaN
# End Time                   43526
# Name: 16, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    take_egg
# Start Time           43526
# Unnamed: 4             NaN
# End Time             53570
# Name: 25, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    crack_egg
# Start Time            53570
# Unnamed: 4              NaN
# End Time              65148
# Name: 32, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    clean_hands
# Start Time              65148
# Unnamed: 4                NaN
# End Time                73601
# Name: 38, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time           73601
# Unnamed: 4             NaN
# End Time             79787
# Name: 44, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      79787
# Unnamed: 4                        NaN
# End Time                        92127
# Name: 47, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time           92127
# Unnamed: 4             NaN
# End Time            123166
# Name: 55, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 123166
# Unnamed: 4                    NaN
# End Time                   196355
# Name: 59, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   196355
# Unnamed: 4                      NaN
# End Time                     210302
# Name: 70, dtype: object
# S09_Eggs_8421130.npy
# Grouped Labels    clean_hands
# Start Time             210302
# Unnamed: 4                NaN
# End Time               216300
# Name: 76, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    put_pan
# Start Time          10559
# End Time            23179
# Name: 1, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    put_oil_butter
# Start Time                 23179
# End Time                   38668
# Name: 6, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    take_egg
# Start Time           38668
# End Time             44453
# Name: 16, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    take_bowl
# Start Time            44453
# End Time              50535
# Name: 21, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    crack_egg
# Start Time            50535
# End Time              63168
# Name: 26, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time           63168
# End Time             83456
# Name: 33, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      83456
# End Time                        94735
# Name: 40, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time           94735
# End Time            102863
# Name: 49, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 102863
# End Time                   144229
# Name: 53, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time          144229
# End Time            161565
# Name: 60, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    take_plate
# Start Time            161565
# End Time              167571
# Name: 64, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167571
# End Time                     184602
# Name: 68, dtype: object
# S11_Eggs_6510211.npy
# Grouped Labels    remove_utensils
# Start Time                 184602
# End Time                   194080
# Name: 74, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    put_pan
# Start Time          10559
# End Time            23179
# Name: 1, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    put_oil_butter
# Start Time                 23179
# End Time                   38668
# Name: 6, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    take_egg
# Start Time           38668
# End Time             44453
# Name: 16, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    take_bowl
# Start Time            44453
# End Time              50535
# Name: 21, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    crack_egg
# Start Time            50535
# End Time              63168
# Name: 26, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time           63168
# End Time             83456
# Name: 33, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      83456
# End Time                        94735
# Name: 40, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time           94735
# End Time            102863
# Name: 49, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 102863
# End Time                   144229
# Name: 53, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time          144229
# End Time            161565
# Name: 60, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    take_plate
# Start Time            161565
# End Time              167571
# Name: 64, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167571
# End Time                     184602
# Name: 68, dtype: object
# S11_Eggs_7150991.npy
# Grouped Labels    remove_utensils
# Start Time                 184602
# End Time                   194080
# Name: 74, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    put_pan
# Start Time          10559
# End Time            23179
# Name: 1, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    put_oil_butter
# Start Time                 23179
# End Time                   38668
# Name: 6, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    take_egg
# Start Time           38668
# End Time             44453
# Name: 16, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    take_bowl
# Start Time            44453
# End Time              50535
# Name: 21, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    crack_egg
# Start Time            50535
# End Time              63168
# Name: 26, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time           63168
# End Time             83456
# Name: 33, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      83456
# End Time                        94735
# Name: 40, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time           94735
# End Time            102863
# Name: 49, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 102863
# End Time                   144229
# Name: 53, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time          144229
# End Time            161565
# Name: 60, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    take_plate
# Start Time            161565
# End Time              167571
# Name: 64, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167571
# End Time                     184602
# Name: 68, dtype: object
# S11_Eggs_7151020.npy
# Grouped Labels    remove_utensils
# Start Time                 184602
# End Time                   194080
# Name: 74, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    put_pan
# Start Time          10559
# End Time            23179
# Name: 1, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    put_oil_butter
# Start Time                 23179
# End Time                   38668
# Name: 6, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    take_egg
# Start Time           38668
# End Time             44453
# Name: 16, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    take_bowl
# Start Time            44453
# End Time              50535
# Name: 21, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    crack_egg
# Start Time            50535
# End Time              63168
# Name: 26, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time           63168
# End Time             83456
# Name: 33, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      83456
# End Time                        94735
# Name: 40, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time           94735
# End Time            102863
# Name: 49, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 102863
# End Time                   144229
# Name: 53, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time          144229
# End Time            161565
# Name: 60, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    take_plate
# Start Time            161565
# End Time              167571
# Name: 64, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167571
# End Time                     184602
# Name: 68, dtype: object
# S11_Eggs_7151062.npy
# Grouped Labels    remove_utensils
# Start Time                 184602
# End Time                   194080
# Name: 74, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    put_pan
# Start Time          10559
# End Time            23179
# Name: 1, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    put_oil_butter
# Start Time                 23179
# End Time                   38668
# Name: 6, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    take_egg
# Start Time           38668
# End Time             44453
# Name: 16, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    take_bowl
# Start Time            44453
# End Time              50535
# Name: 21, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    crack_egg
# Start Time            50535
# End Time              63168
# Name: 26, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time           63168
# End Time             83456
# Name: 33, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      83456
# End Time                        94735
# Name: 40, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time           94735
# End Time            102863
# Name: 49, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 102863
# End Time                   144229
# Name: 53, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time          144229
# End Time            161565
# Name: 60, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    take_plate
# Start Time            161565
# End Time              167571
# Name: 64, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167571
# End Time                     184602
# Name: 68, dtype: object
# S11_Eggs_8421130.npy
# Grouped Labels    remove_utensils
# Start Time                 184602
# End Time                   194080
# Name: 74, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    put_pan
# Start Time          11333
# End Time            27259
# Name: 1, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    put_oil_butter
# Start Time                 27259
# End Time                   54430
# Name: 6, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    take_bowl
# Start Time            54430
# End Time              62062
# Name: 17, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    take_egg
# Start Time           62062
# End Time             82084
# Name: 21, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    crack_egg
# Start Time            82084
# End Time              90794
# Name: 32, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time           90794
# End Time            105918
# Name: 35, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     105918
# End Time                       120605
# Name: 38, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time          120605
# End Time            142077
# Name: 45, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 142077
# End Time                   159822
# Name: 50, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    take_plate
# Start Time            159822
# End Time              167177
# Name: 54, dtype: object
# S12_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167177
# End Time                     237083
# Name: 58, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    put_pan
# Start Time          11333
# End Time            27259
# Name: 1, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    put_oil_butter
# Start Time                 27259
# End Time                   54430
# Name: 6, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    take_bowl
# Start Time            54430
# End Time              62062
# Name: 17, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    take_egg
# Start Time           62062
# End Time             82084
# Name: 21, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    crack_egg
# Start Time            82084
# End Time              90794
# Name: 32, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time           90794
# End Time            105918
# Name: 35, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     105918
# End Time                       120605
# Name: 38, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time          120605
# End Time            142077
# Name: 45, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 142077
# End Time                   159822
# Name: 50, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    take_plate
# Start Time            159822
# End Time              167177
# Name: 54, dtype: object
# S12_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167177
# End Time                     237083
# Name: 58, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    put_pan
# Start Time          11333
# End Time            27259
# Name: 1, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    put_oil_butter
# Start Time                 27259
# End Time                   54430
# Name: 6, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    take_bowl
# Start Time            54430
# End Time              62062
# Name: 17, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    take_egg
# Start Time           62062
# End Time             82084
# Name: 21, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    crack_egg
# Start Time            82084
# End Time              90794
# Name: 32, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time           90794
# End Time            105918
# Name: 35, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     105918
# End Time                       120605
# Name: 38, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time          120605
# End Time            142077
# Name: 45, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 142077
# End Time                   159822
# Name: 50, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    take_plate
# Start Time            159822
# End Time              167177
# Name: 54, dtype: object
# S12_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167177
# End Time                     237083
# Name: 58, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    put_pan
# Start Time          11333
# End Time            27259
# Name: 1, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    put_oil_butter
# Start Time                 27259
# End Time                   54430
# Name: 6, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    take_bowl
# Start Time            54430
# End Time              62062
# Name: 17, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    take_egg
# Start Time           62062
# End Time             82084
# Name: 21, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    crack_egg
# Start Time            82084
# End Time              90794
# Name: 32, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time           90794
# End Time            105918
# Name: 35, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     105918
# End Time                       120605
# Name: 38, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time          120605
# End Time            142077
# Name: 45, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 142077
# End Time                   159822
# Name: 50, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    take_plate
# Start Time            159822
# End Time              167177
# Name: 54, dtype: object
# S12_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167177
# End Time                     237083
# Name: 58, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    put_pan
# Start Time          11333
# End Time            27259
# Name: 1, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    put_oil_butter
# Start Time                 27259
# End Time                   54430
# Name: 6, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    take_bowl
# Start Time            54430
# End Time              62062
# Name: 17, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    take_egg
# Start Time           62062
# End Time             82084
# Name: 21, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    crack_egg
# Start Time            82084
# End Time              90794
# Name: 32, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time           90794
# End Time            105918
# Name: 35, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     105918
# End Time                       120605
# Name: 38, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time          120605
# End Time            142077
# Name: 45, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 142077
# End Time                   159822
# Name: 50, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    take_plate
# Start Time            159822
# End Time              167177
# Name: 54, dtype: object
# S12_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   167177
# End Time                     237083
# Name: 58, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    take_egg
# Start Time            9463
# Unnamed: 4             NaN
# End Time             36661
# Name: 1, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    take_bowl
# Start Time            36661
# Unnamed: 4              NaN
# End Time              51241
# Name: 14, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    crack_egg
# Start Time            51241
# Unnamed: 4              NaN
# End Time              71210
# Name: 22, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    clean_hands
# Start Time              71210
# Unnamed: 4                NaN
# End Time                76685
# Name: 28, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    take_mixing_tool
# Start Time                   76685
# Unnamed: 4              take_spoon
# End Time                     80143
# Name: 33, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      80143
# Unnamed: 4                        NaN
# End Time                       101239
# Name: 37, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time          101239
# Unnamed: 4             NaN
# End Time            112192
# Name: 51, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    put_pan
# Start Time         112192
# Unnamed: 4            NaN
# End Time           131941
# Name: 55, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time          131941
# Unnamed: 4             NaN
# End Time            172822
# Name: 63, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     172822
# Unnamed: 4                        NaN
# End Time                       175906
# Name: 70, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time          175906
# Unnamed: 4             NaN
# End Time            180405
# Name: 73, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     180405
# Unnamed: 4                        NaN
# End Time                       191129
# Name: 77, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time          191129
# Unnamed: 4             NaN
# End Time            214782
# Name: 86, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    put_oil_butter
# Start Time                214782
# Unnamed: 4                   NaN
# End Time                  227010
# Name: 97, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 227010
# Unnamed: 4                    NaN
# End Time                   301360
# Name: 102, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    clean_hands
# Start Time             301360
# Unnamed: 4                NaN
# End Time               330890
# Name: 116, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    take_plate
# Start Time            330890
# Unnamed: 4               NaN
# End Time              338346
# Name: 127, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    put_oil_butter
# Start Time                338346
# Unnamed: 4                   NaN
# End Time                  383577
# Name: 132, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    clean_hands
# Start Time             383577
# Unnamed: 4                NaN
# End Time               385333
# Name: 152, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   385333
# Unnamed: 4                      NaN
# End Time                     433326
# Name: 155, dtype: object
# S13_Eggs_6510211.npy
# Grouped Labels    clean_hands
# Start Time             433326
# Unnamed: 4                NaN
# End Time               445199
# Name: 175, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    take_egg
# Start Time            9463
# Unnamed: 4             NaN
# End Time             36661
# Name: 1, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    take_bowl
# Start Time            36661
# Unnamed: 4              NaN
# End Time              51241
# Name: 14, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    crack_egg
# Start Time            51241
# Unnamed: 4              NaN
# End Time              71210
# Name: 22, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    clean_hands
# Start Time              71210
# Unnamed: 4                NaN
# End Time                76685
# Name: 28, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    take_mixing_tool
# Start Time                   76685
# Unnamed: 4              take_spoon
# End Time                     80143
# Name: 33, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      80143
# Unnamed: 4                        NaN
# End Time                       101239
# Name: 37, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time          101239
# Unnamed: 4             NaN
# End Time            112192
# Name: 51, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    put_pan
# Start Time         112192
# Unnamed: 4            NaN
# End Time           131941
# Name: 55, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time          131941
# Unnamed: 4             NaN
# End Time            172822
# Name: 63, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     172822
# Unnamed: 4                        NaN
# End Time                       175906
# Name: 70, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time          175906
# Unnamed: 4             NaN
# End Time            180405
# Name: 73, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     180405
# Unnamed: 4                        NaN
# End Time                       191129
# Name: 77, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time          191129
# Unnamed: 4             NaN
# End Time            214782
# Name: 86, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    put_oil_butter
# Start Time                214782
# Unnamed: 4                   NaN
# End Time                  227010
# Name: 97, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 227010
# Unnamed: 4                    NaN
# End Time                   301360
# Name: 102, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    clean_hands
# Start Time             301360
# Unnamed: 4                NaN
# End Time               330890
# Name: 116, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    take_plate
# Start Time            330890
# Unnamed: 4               NaN
# End Time              338346
# Name: 127, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    put_oil_butter
# Start Time                338346
# Unnamed: 4                   NaN
# End Time                  383577
# Name: 132, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    clean_hands
# Start Time             383577
# Unnamed: 4                NaN
# End Time               385333
# Name: 152, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   385333
# Unnamed: 4                      NaN
# End Time                     433326
# Name: 155, dtype: object
# S13_Eggs_7150991.npy
# Grouped Labels    clean_hands
# Start Time             433326
# Unnamed: 4                NaN
# End Time               445199
# Name: 175, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    take_egg
# Start Time            9463
# Unnamed: 4             NaN
# End Time             36661
# Name: 1, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    take_bowl
# Start Time            36661
# Unnamed: 4              NaN
# End Time              51241
# Name: 14, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    crack_egg
# Start Time            51241
# Unnamed: 4              NaN
# End Time              71210
# Name: 22, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    clean_hands
# Start Time              71210
# Unnamed: 4                NaN
# End Time                76685
# Name: 28, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    take_mixing_tool
# Start Time                   76685
# Unnamed: 4              take_spoon
# End Time                     80143
# Name: 33, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      80143
# Unnamed: 4                        NaN
# End Time                       101239
# Name: 37, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time          101239
# Unnamed: 4             NaN
# End Time            112192
# Name: 51, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    put_pan
# Start Time         112192
# Unnamed: 4            NaN
# End Time           131941
# Name: 55, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time          131941
# Unnamed: 4             NaN
# End Time            172822
# Name: 63, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     172822
# Unnamed: 4                        NaN
# End Time                       175906
# Name: 70, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time          175906
# Unnamed: 4             NaN
# End Time            180405
# Name: 73, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                     180405
# Unnamed: 4                        NaN
# End Time                       191129
# Name: 77, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time          191129
# Unnamed: 4             NaN
# End Time            214782
# Name: 86, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    put_oil_butter
# Start Time                214782
# Unnamed: 4                   NaN
# End Time                  227010
# Name: 97, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 227010
# Unnamed: 4                    NaN
# End Time                   301360
# Name: 102, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    clean_hands
# Start Time             301360
# Unnamed: 4                NaN
# End Time               330890
# Name: 116, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    take_plate
# Start Time            330890
# Unnamed: 4               NaN
# End Time              338346
# Name: 127, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    put_oil_butter
# Start Time                338346
# Unnamed: 4                   NaN
# End Time                  383577
# Name: 132, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    clean_hands
# Start Time             383577
# Unnamed: 4                NaN
# End Time               385333
# Name: 152, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   385333
# Unnamed: 4                      NaN
# End Time                     433326
# Name: 155, dtype: object
# S13_Eggs_7151020.npy
# Grouped Labels    clean_hands
# Start Time             433326
# Unnamed: 4                NaN
# End Time               445199
# Name: 175, dtype: object
# S13_Eggs_7151062.npy
# Grouped Labels    take_egg
# Start Time            9463
# Unnamed: 4             NaN
# End Time             36661
# Name: 1, dtype: object
# S13_Eggs_7151062.npy
# Grouped Labels    take_bowl
# Start Time            36661
# Unnamed: 4              NaN
# End Time              51241
# Name: 14, dtype: object
# S13_Eggs_7151062.npy
# Grouped Labels    crack_egg
# Start Time            51241
# Unnamed: 4              NaN
# End Time              71210
# Name: 22, dtype: object
# S13_Eggs_7151062.npy
# Grouped Labels    clean_hands
# ...
# S54_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time           98722
# Unnamed: 4             NaN
# End Time            123073
# Name: 63, dtype: object
# S54_Eggs_7151020.npy
# Grouped Labels    take_plate
# Start Time            123073
# Unnamed: 4               NaN
# End Time              131252
# Name: 66, dtype: object
# S54_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 131252
# Unnamed: 4                    NaN
# End Time                   161420
# Name: 72, dtype: object
# S54_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   161420
# Unnamed: 4                      NaN
# End Time                     245698
# Name: 89, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    take_egg
# Start Time            7142
# Unnamed: 4             NaN
# End Time             17378
# Name: 1, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    put_pan
# Start Time          17378
# Unnamed: 4            NaN
# End Time            31828
# Name: 7, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    crack_egg
# Start Time            31828
# Unnamed: 4              NaN
# End Time              54488
# Name: 11, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    clean_hands
# Start Time              54488
# Unnamed: 4                NaN
# End Time                60770
# Name: 29, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    take_mixing_tool
# Start Time                   60770
# Unnamed: 4              take_whisk
# End Time                     63663
# Name: 34, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      63663
# Unnamed: 4                        NaN
# End Time                        76007
# Name: 37, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    put_oil_butter
# Start Time                 76007
# Unnamed: 4                   NaN
# End Time                   98722
# Name: 48, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time           98722
# Unnamed: 4             NaN
# End Time            123073
# Name: 63, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    take_plate
# Start Time            123073
# Unnamed: 4               NaN
# End Time              131252
# Name: 66, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 131252
# Unnamed: 4                    NaN
# End Time                   161420
# Name: 72, dtype: object
# S54_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   161420
# Unnamed: 4                      NaN
# End Time                     245698
# Name: 89, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    take_egg
# Start Time            7142
# Unnamed: 4             NaN
# End Time             17378
# Name: 1, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    put_pan
# Start Time          17378
# Unnamed: 4            NaN
# End Time            31828
# Name: 7, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    crack_egg
# Start Time            31828
# Unnamed: 4              NaN
# End Time              54488
# Name: 11, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    clean_hands
# Start Time              54488
# Unnamed: 4                NaN
# End Time                60770
# Name: 29, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    take_mixing_tool
# Start Time                   60770
# Unnamed: 4              take_whisk
# End Time                     63663
# Name: 34, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      63663
# Unnamed: 4                        NaN
# End Time                        76007
# Name: 37, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    put_oil_butter
# Start Time                 76007
# Unnamed: 4                   NaN
# End Time                   98722
# Name: 48, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time           98722
# Unnamed: 4             NaN
# End Time            123073
# Name: 63, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    take_plate
# Start Time            123073
# Unnamed: 4               NaN
# End Time              131252
# Name: 66, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 131252
# Unnamed: 4                    NaN
# End Time                   161420
# Name: 72, dtype: object
# S54_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   161420
# Unnamed: 4                      NaN
# End Time                     245698
# Name: 89, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    take_egg
# Start Time            9709
# Unnamed: 4             NaN
# End Time             26288
# Name: 1, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    put_pan
# Start Time          26288
# Unnamed: 4            NaN
# End Time            35171
# Name: 10, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    take_plate
# Start Time             35171
# Unnamed: 4               NaN
# End Time               38696
# Name: 16, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    take_salt_and_pepper_shaker
# Start Time                              38696
# Unnamed: 4                                NaN
# End Time                                43193
# Name: 19, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    put_oil_butter
# Start Time                 43193
# Unnamed: 4                   NaN
# End Time                   62020
# Name: 23, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    take_mixing_tool
# Start Time                   62020
# Unnamed: 4              take_whisk
# End Time                     65119
# Name: 33, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    crack_egg
# Start Time            65119
# Unnamed: 4              NaN
# End Time              86816
# Name: 37, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      86816
# Unnamed: 4                        NaN
# End Time                        96502
# Name: 51, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    stir_egg
# Start Time           96502
# Unnamed: 4             NaN
# End Time            109449
# Name: 57, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 109449
# Unnamed: 4                    NaN
# End Time                   131110
# Name: 63, dtype: object
# S55_Eggs_6510211.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   131110
# Unnamed: 4                      NaN
# End Time                     246270
# Name: 73, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    take_egg
# Start Time            9709
# Unnamed: 4             NaN
# End Time             26288
# Name: 1, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    put_pan
# Start Time          26288
# Unnamed: 4            NaN
# End Time            35171
# Name: 10, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    take_plate
# Start Time             35171
# Unnamed: 4               NaN
# End Time               38696
# Name: 16, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    take_salt_and_pepper_shaker
# Start Time                              38696
# Unnamed: 4                                NaN
# End Time                                43193
# Name: 19, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    put_oil_butter
# Start Time                 43193
# Unnamed: 4                   NaN
# End Time                   62020
# Name: 23, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    take_mixing_tool
# Start Time                   62020
# Unnamed: 4              take_whisk
# End Time                     65119
# Name: 33, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    crack_egg
# Start Time            65119
# Unnamed: 4              NaN
# End Time              86816
# Name: 37, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      86816
# Unnamed: 4                        NaN
# End Time                        96502
# Name: 51, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    stir_egg
# Start Time           96502
# Unnamed: 4             NaN
# End Time            109449
# Name: 57, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 109449
# Unnamed: 4                    NaN
# End Time                   131110
# Name: 63, dtype: object
# S55_Eggs_7150991.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   131110
# Unnamed: 4                      NaN
# End Time                     246270
# Name: 73, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    take_egg
# Start Time            9709
# Unnamed: 4             NaN
# End Time             26288
# Name: 1, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    put_pan
# Start Time          26288
# Unnamed: 4            NaN
# End Time            35171
# Name: 10, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    take_plate
# Start Time             35171
# Unnamed: 4               NaN
# End Time               38696
# Name: 16, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    take_salt_and_pepper_shaker
# Start Time                              38696
# Unnamed: 4                                NaN
# End Time                                43193
# Name: 19, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    put_oil_butter
# Start Time                 43193
# Unnamed: 4                   NaN
# End Time                   62020
# Name: 23, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    take_mixing_tool
# Start Time                   62020
# Unnamed: 4              take_whisk
# End Time                     65119
# Name: 33, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    crack_egg
# Start Time            65119
# Unnamed: 4              NaN
# End Time              86816
# Name: 37, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      86816
# Unnamed: 4                        NaN
# End Time                        96502
# Name: 51, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    stir_egg
# Start Time           96502
# Unnamed: 4             NaN
# End Time            109449
# Name: 57, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 109449
# Unnamed: 4                    NaN
# End Time                   131110
# Name: 63, dtype: object
# S55_Eggs_7150996.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   131110
# Unnamed: 4                      NaN
# End Time                     246270
# Name: 73, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    take_egg
# Start Time            9709
# Unnamed: 4             NaN
# End Time             26288
# Name: 1, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    put_pan
# Start Time          26288
# Unnamed: 4            NaN
# End Time            35171
# Name: 10, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    take_plate
# Start Time             35171
# Unnamed: 4               NaN
# End Time               38696
# Name: 16, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    take_salt_and_pepper_shaker
# Start Time                              38696
# Unnamed: 4                                NaN
# End Time                                43193
# Name: 19, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    put_oil_butter
# Start Time                 43193
# Unnamed: 4                   NaN
# End Time                   62020
# Name: 23, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    take_mixing_tool
# Start Time                   62020
# Unnamed: 4              take_whisk
# End Time                     65119
# Name: 33, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    crack_egg
# Start Time            65119
# Unnamed: 4              NaN
# End Time              86816
# Name: 37, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      86816
# Unnamed: 4                        NaN
# End Time                        96502
# Name: 51, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    stir_egg
# Start Time           96502
# Unnamed: 4             NaN
# End Time            109449
# Name: 57, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 109449
# Unnamed: 4                    NaN
# End Time                   131110
# Name: 63, dtype: object
# S55_Eggs_7151020.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   131110
# Unnamed: 4                      NaN
# End Time                     246270
# Name: 73, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    take_egg
# Start Time            9709
# Unnamed: 4             NaN
# End Time             26288
# Name: 1, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    put_pan
# Start Time          26288
# Unnamed: 4            NaN
# End Time            35171
# Name: 10, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    take_plate
# Start Time             35171
# Unnamed: 4               NaN
# End Time               38696
# Name: 16, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    take_salt_and_pepper_shaker
# Start Time                              38696
# Unnamed: 4                                NaN
# End Time                                43193
# Name: 19, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    put_oil_butter
# Start Time                 43193
# Unnamed: 4                   NaN
# End Time                   62020
# Name: 23, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    take_mixing_tool
# Start Time                   62020
# Unnamed: 4              take_whisk
# End Time                     65119
# Name: 33, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    crack_egg
# Start Time            65119
# Unnamed: 4              NaN
# End Time              86816
# Name: 37, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      86816
# Unnamed: 4                        NaN
# End Time                        96502
# Name: 51, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    stir_egg
# Start Time           96502
# Unnamed: 4             NaN
# End Time            109449
# Name: 57, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 109449
# Unnamed: 4                    NaN
# End Time                   131110
# Name: 63, dtype: object
# S55_Eggs_7151062.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   131110
# Unnamed: 4                      NaN
# End Time                     246270
# Name: 73, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    take_egg
# Start Time            9709
# Unnamed: 4             NaN
# End Time             26288
# Name: 1, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    put_pan
# Start Time          26288
# Unnamed: 4            NaN
# End Time            35171
# Name: 10, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    take_plate
# Start Time             35171
# Unnamed: 4               NaN
# End Time               38696
# Name: 16, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    take_salt_and_pepper_shaker
# Start Time                              38696
# Unnamed: 4                                NaN
# End Time                                43193
# Name: 19, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    put_oil_butter
# Start Time                 43193
# Unnamed: 4                   NaN
# End Time                   62020
# Name: 23, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    take_mixing_tool
# Start Time                   62020
# Unnamed: 4              take_whisk
# End Time                     65119
# Name: 33, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    crack_egg
# Start Time            65119
# Unnamed: 4              NaN
# End Time              86816
# Name: 37, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    add_salt_and_pepper
# Start Time                      86816
# Unnamed: 4                        NaN
# End Time                        96502
# Name: 51, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    stir_egg
# Start Time           96502
# Unnamed: 4             NaN
# End Time            109449
# Name: 57, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_pan
# Start Time                 109449
# Unnamed: 4                    NaN
# End Time                   131110
# Name: 63, dtype: object
# S55_Eggs_8421130.npy
# Grouped Labels    put_eggs_on_plate
# Start Time                   131110
# Unnamed: 4                      NaN
# End Time                     246270
# Name: 73, dtype: object

# %%
#PRINT gt files

# %%
# !pwd

# %%
brozone = r"C:\Users\dcsang\PycharmProjects\embedding\breakfast\Breakfast_fs\groundTruth_maxpool_clean_splits\split1\test"
temp_path2 = os.path.join(brozone, "P03_cam01_P03_cereals.txt")

# temp_path2 = os.path.join(gt_maxpool_dir, "S36_Brownie_6510211.txt")
with open(temp_path2, "r") as f:
    blah = f.readlines()
blah

# %%
subject[0].split("_")[0] in gt_all.keys()

# %%
blah = np.arange(100).reshape(5,20)

# %%
blah

# %%
blah2 = blah.max(axis=0)

# %%
blah2

# %%
path = r"C:\Users\dcsang\PycharmProjects\embedding\cmu-kitchen-capture\Brownie\S07_Brownie_Video"
file = "S07_Brownie_6510211-1103.avi"
vid_path = os.path.join(path,file)

# %%
v = cv2.VideoCapture(vid_path)

# %%
v.set(cv2.CAP_PROP_POS_AVI_RATIO,1)
v.get(cv2.CAP_PROP_POS_MSEC)

import cv2

cap = cv2.VideoCapture(vid_path)
fps = cap.get(cv2.CAP_PROP_FPS)      # OpenCV2 version 2 used "CV_CAP_PROP_FPS"
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
duration = frame_count/fps

print('fps = ' + str(fps))
print('number of frames = ' + str(frame_count))
print('duration (S) = ' + str(duration))
minutes = int(duration/60)
seconds = duration%60
print('duration (M:S) = ' + str(minutes) + ':' + str(seconds))

cap.release()

# %%
# >>> v=cv2.VideoCapture('sample.avi')
# >>> v.set(cv2.CAP_PROP_POS_AVI_RATIO,1)
# True
# >>> v.get(cv2.CAP_PROP_POS_MSEC)
# 213400.0

# %%
temp_dir = r"C:\Users\dcsang\PycharmProjects\embedding\cmu-kitchen-capture\features\Brownie"
for file in os.listdir(temp_dir)[1:]:
    try:
        subject = file.split("_")[0]
        temp = np.load(os.path.join(temp_dir, file))
        print(temp.shape, gt_all[subject].shape)
    except Exception as e:
        print(file, e)

# %%
temp_file=r"C:\Users\dcsang\PycharmProjects\embedding\cmu-kitchen-capture\features\Brownie\S36_Brownie_6510211.npy"
temp_feat = np.load(temp_file)
print(temp_feat.shape)
temp_feat_maxpool = get_maxpool_feats(feat, gt_all["S35"])

# %%
temp_feat[217:216].max(axis=0).shape
# gt_all["S35"]
